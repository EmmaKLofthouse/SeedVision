# %% [markdown]
# <a href="https://colab.research.google.com/github/EmmaKLofthouse/SeedVision/blob/inception_model/SeedVision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive/", force_remount=True)
# Out:
# Mounted at /content/drive/

# %% [markdown]
# # SeedVision
#
# This notebook shows how to use the trained models to classify one of your own images.

# %% [markdown]
# # Load Modules

# %%
# General
import numpy as np
import os
import cv2

# TensorFlow
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img
from tensorflow.keras.models import Sequential

#Plotting
import matplotlib.pyplot as plt

# %% [markdown]
# # Load model
#
# Choose the desired model. Currently available are:
#
# **model_inception** uses transfer learning and the InceptionV3 model as in seed_inception.ipynb

# %%
model_name = "model_inceptionV3"
YOUR_MODEL_PATH = '/content/drive/MyDrive/Projects/SeedVision/models'
model = load_model(os.path.join(YOUR_MODEL_PATH ,model_name))

# %% [markdown]
# # Load your image
#
# Load in your image and apply the required transformations.

# %%
YOUR_IMAGE_PATH = '/content/drive/MyDrive/Projects/SeedVision/test/Sunflower/Sunflower100.jpg'
img_path = YOUR_IMAGE_PATH
img = cv2.cvtColor(cv2.imread(img_path), cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()

# %% [markdown]
# # Make the prediction!
#
# And now we can use the model to predict the mostly likely vegetable from the currently available categories.

# %%
categories = ["Almond","Apple","Avocado","Brussel Sprout","Carrot","Jackfruit","Lemon","Lychee",
              "Mango","Olive","Poppy","Pumpkin","Sunflower","Tomato"]
resize = tf.image.resize(img, (256,256))
predicted_probs = model.predict(np.expand_dims(resize/255, 0), verbose=False)
predicted_class = np.argmax(predicted_probs)
print(f"Predicted class is {categories[predicted_class]}")
# Out:
# Predicted class is Sunflower
